# %% [markdown]
# ### Q9_a: Calculate Skewness, Kurtosis & draw inferences on the following data
#       Cars speed and distance

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv("Q9_a (2).csv")

# %%
df['Index'].sort_values(ascending=True)
df['speed'].sort_values(ascending=True)
df['dist'].sort_values(ascending=True)
df.skew()
# Out:
# Index    0.000000
# speed   -0.117510
# dist     0.806895
# dtype: float64

# %%
df.kurt()
# Out:
# Index   -1.200000
# speed   -0.508994
# dist     0.405053
# dtype: float64

# %%
from statistics import mode 
mode(df['dist'])
# Out:
# 26

# %%
f,ax=plt.subplots(figsize=(15,5))
plt.subplot(1,3,1)
sns.distplot(df.Index)
plt.subplot(1,3,2)
sns.distplot(df.speed)
plt.subplot(1,3,3)
sns.distplot(df.dist)
plt.show();

# %%
#speed data is negatively skewed

# %%
sns.distplot(df['speed'],hist=False,color='blue')
sns.distplot(df['dist'],hist=False,color='Green');

# %% [markdown]
# ### Q9_b: Calculate Skewness, Kurtosis & draw inferences on the following data
#       Cars speed and distance

# %%
df2= pd.read_csv("Q9_b.csv")

# %%
df2.skew()
# Out:
# Unnamed: 0    0.000000
# SP            1.611450
# WT           -0.614753
# dtype: float64

# %%
df2.kurt()
# Out:
# Unnamed: 0   -1.200000
# SP            2.977329
# WT            0.950291
# dtype: float64

# %%
sns.distplot(df2['SP'],hist=False,color='blue')
sns.distplot(df2['WT'],hist=False,color='Green');

# %%
sns.distplot(df2['SP'],color='blue');  #is postilvely skewed

# %%
sns.distplot(df2['WT'],color='Green');   #is negatively skewed

# %% [markdown]
# ### Q11)  Suppose we want to estimate the average weight of an adult male in    Mexico. We draw a random sample of 2,000 men from a population of 3,000,000 men and weigh them. We find that the average person in our sample weighs 200 pounds, and the standard deviation of the sample is 30 pounds. Calculate 94%,98%,96% confidence interval?

# %% [raw]
# # sample mean = 200 and Standard deviation of sample =30
#
# For calculating CI for 98% , 96%, 94%

# %%
from scipy import stats
import math

# %%
#for CL 98% z score value
z=stats.norm.ppf(0.98)

# %%
z
# Out:
# 2.0537489106318225

# %%
data_sample=2000

# %%
smean_x=200

# %%
sd=30

# %%
rv= z*(sd/math.sqrt(data_sample))

# %%
#CI for 98%
((smean_x-rv),(smean_x+rv))
# Out:
# (198.62230334813333, 201.37769665186667)

# %%
#CI for 98%
stats.norm.interval(0.98,
                   loc=200,
                   scale=30)
# Out:
# (130.2095637787748, 269.7904362212252)

# %%
#CI for 96%
stats.norm.interval(0.96,
                   loc=200,
                   scale=30)
# Out:
# (138.38753268104531, 261.61246731895466)

# %%
#CI for 94%
stats.norm.interval(0.94,
                   loc=200,
                   scale=30)
# Out:
# (143.57619175546247, 256.42380824453755)

# %% [markdown]
# ### Q12)  Below are the scores obtained by a student in tests
# 34,36,36,38,38,39,39,40,40,41,41,41,41,42,42,45,49,56
# 1)	Find mean, median, variance, standard deviation.
# 2)	What can we say about the student marks?

# %%
data = np.array([34,36,36,38,38,39,39,40,40,41,41,41,41,42,42,45,49,56])

# %%
print('Mean = ',data.mean())
print('Median = ',np.median(data))
print('Varieance = ',round(data.var(),3))
print('Standard Deviation = ',round(data.std(),3))
# Out:
# Mean =  41.0
# Median =  40.5
# Varieance =  24.111
# Standard Deviation =  4.91

# %% [markdown]
# #Comments about student's marks :
# ##1)Most of the students have scored 41
# ##2)Highest score is 56 which is outlier
# ##3) Mean > median hence its Positively skewed

# %% [markdown]
# ### Q 20) Calculate probability from the given dataset for the below cases
#
# Data _set: Cars.csv
# Calculate the probability of MPG  of Cars for the below cases.
#        MPG <- Cars$MPG

# %%
from scipy import stats 
cars=pd.read_csv("cars (1).csv")

# %%
cars
# Out:
#      HP        MPG  VOL          SP         WT
# 0   236  12.101263  107  139.840817  34.948615
# 1   175  18.762837  129  132.864163  42.778219
# 2   140  19.086341  160  124.715241  52.997752
# 3   140  19.086341  129  121.864163  42.618698
# 4   238  19.197888  115  150.576579  37.923113
# ..  ...        ...  ...         ...        ...
# 76   55  50.013401   92  105.461264  30.466833
# 77   55  50.013401   92  105.461264  30.193597
# 78   55  50.013401   92  105.461264  30.308480
# 79   53  50.504232   92  104.461264  29.889149
# 80   49  53.700681   89  104.185353  28.762059
#
# [81 rows x 5 columns]

# %% [markdown]
# #### a.	P(MPG>38)

# %%
stats.norm.cdf(38,
              loc = cars.MPG.mean(),
              scale = cars.MPG.std())
# Out:
# 0.6524060748417283

# %% [markdown]
# #### b.	P(MPG<40)

# %%
stats.norm.cdf(40,
              loc = cars.MPG.mean(),
              scale = cars.MPG.std())
# Out:
# 0.7293498762151607

# %% [markdown]
# #### c.    P (20<MPG<50)

# %%
# p(50) - p(20)
(stats.norm.cdf(50,
              loc = cars.MPG.mean(),
              scale = cars.MPG.std()))-(stats.norm.cdf(20,
              loc = cars.MPG.mean(),
              scale = cars.MPG.std()))
# Out:
# 0.8988689169682047

# %% [markdown]
# ### Q_21 Q 21) Check whether the data follows normal distribution
# a)	Check whether the MPG of Cars follows Normal Distribution
#         Dataset: Cars.csv
# b)	Check Whether the Adipose Tissue (AT) and Waist Circumference(Waist)  from wc-at data set  follows Normal Distribution

# %%
#a) MPG does not follow a Normal Distribution
sns.distplot(cars.MPG);

# %%
wa=pd.read_csv("wc-at.csv")

# %%
cars.MPG.skew()
# Out:
# -0.17794674747025732

# %%
cars.MPG.kurt()
# Out:
# -0.6116786559430905

# %%
wa.head()
# Out:
#    Waist     AT
# 0  74.75  25.72
# 1  72.60  25.89
# 2  81.80  42.60
# 3  83.95  42.80
# 4  74.65  29.84

# %%
sns.distplot(wa.Waist);

# %%
sns.distplot(wa.AT);

# %%
#b) Waist & AT does not follow a normal distributionn

# %%
wa.Waist.skew(), wa.Waist.kurt()
# Out:
# (0.1340560824786468, -1.1026666011768886)

# %%
wa.AT.skew(), wa.AT.kurt()
# Out:
# (0.584869324127853, -0.28557567504584425)

# %% [markdown]
# ### Q 22) Calculate the Z scores of 90% confidence interval,94% confidence interval, 60% confidence interval.

# %%
print("z score of 90% :",stats.norm.ppf(0.90))
print("z score of 94% :",stats.norm.ppf(0.94))
print("z score of 60% :",stats.norm.ppf(0.60))
# Out:
# z score of 90% : 1.2815515655446004
# z score of 94% : 1.5547735945968535
# z score of 60% : 0.2533471031357997

# %% [markdown]
# ### Q 23) Calculate the t scores of 95% confidence interval, 96% confidence interval, 99% confidence interval for sample size of 25

# %%
#t score for sample size of 25 whiich is degree of freedom
print("t score of 95% :",stats.t.ppf(.95,df=25-1))
print("t score of 96% :",stats.t.ppf(.96,df=25-1))
print("t score of 99% :",stats.t.ppf(.99,df=25-1))
# Out:
# t score of 95% : 1.7108820799094275
# t score of 96% : 1.8280511719596342
# t score of 99% : 2.4921594731575762

# %% [markdown]
# ### Q 24)   A Government company claims that an average light bulb lasts 270 days. A researcher randomly selects 18 bulbs for testing. The sampled bulbs last an average of 260 days, with a standard deviation of 90 days. If the CEO's claim were true, what is the probability that 18 randomly selected bulbs would have an average life of no more than 260 days

# %%
#to prove probability that 18 randomly selected bulbs would have an average life of no more than 260 days

# %%
#t-score for x=260 // formula : t-score= (smean-pmean)/(S_std/sqrt(n))

# %%
t_score = (260-270)/(90/math.sqrt(18))

# %%
t_score
# Out:
# -0.4714045207910317

# %%
#to find probability P(x)<=260 ?

# %%
stats.t.cdf(t_score,df=18-1)  #for randomly selected 18 bulbs
# Out:
# 0.32167253567098364
